# %% [markdown]
# # IMT TAF Fiabilité : Test de charge
#
# - **durée** 30s

# %%
# %matplotlib inline
# %config InlineBackend.rc = {'font.size': 10, 'figure.figsize': (16.0, 5.0),'figure.dpi': 75}
import pandas as pd
from matplotlib import pyplot as plt #%matplotlib notebook

# %%
d = pd.read_csv('data/stats.csv', parse_dates=['ts'], date_parser=lambda x: pd.to_datetime(x, unit='ms').tz_localize('UTC').tz_convert('Europe/Paris'),
                                names=['id','ts','path','latency','res','res_desc'])
d["grouppath"] = d.apply(lambda x: "/".join(x['path'].split("/")[:2]), axis=1)
sorted_data = d.sample(33).sort_values(by="latency" , ascending = False)
filterd_data = sorted_data[sorted_data["grouppath"] == "/order"]
filterd_data
# Out:
# /var/folders/0h/crjpwv4n1kl1tc30x1vhjhf80000gn/T/ipykernel_20261/785509217.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   d = pd.read_csv('data/stats.csv', parse_dates=['ts'], date_parser=lambda x: pd.to_datetime(x, unit='ms').tz_localize('UTC').tz_convert('Europe/Paris'),
# /var/folders/0h/crjpwv4n1kl1tc30x1vhjhf80000gn/T/ipykernel_20261/785509217.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   d = pd.read_csv('data/stats.csv', parse_dates=['ts'], date_parser=lambda x: pd.to_datetime(x, unit='ms').tz_localize('UTC').tz_convert('Europe/Paris'),
#              id                               ts  \
# 1817        577 2024-11-17 16:11:29.231000+01:00
# 1930  900000399 2024-11-17 16:11:30.885000+01:00
# 1805        732 2024-11-17 16:11:30.937000+01:00
# 1294        370 2024-11-17 16:11:26.940000+01:00
# 2070  900001188 2024-11-17 16:11:38.264000+01:00
# 1413        785 2024-11-17 16:11:31.529000+01:00
# 786   900000083 2024-11-17 16:11:26.646000+01:00
# 1504       1338 2024-11-17 16:11:37.668000+01:00
# 783   900000283 2024-11-17 16:11:29.347000+01:00
# 357         237 2024-11-17 16:11:25.464000+01:00
# 1856       1752 2024-11-17 16:11:42.294000+01:00
# 186         100 2024-11-17 16:11:23.957000+01:00
# 1810       1820 2024-11-17 16:11:43.042000+01:00
# 914   900000607 2024-11-17 16:11:33.562000+01:00
# 303   900000214 2024-11-17 16:11:27.462000+01:00
# 207   900000060 2024-11-17 16:11:26.143000+01:00
# 43            7 2024-11-17 16:11:22.932000+01:00
# 1948       2104 2024-11-17 16:11:46.176000+01:00
# 1792       1955 2024-11-17 16:11:44.534000+01:00
# 2109       2316 2024-11-17 16:11:48.534000+01:00
# 1519  900001495 2024-11-17 16:11:41.569000+01:00
# 466         714 2024-11-17 16:11:30.739000+01:00
# 1562  900001559 2024-11-17 16:11:42.785000+01:00
# 1804  900001878 2024-11-17 16:11:47.683000+01:00
# 839   900000955 2024-11-17 16:11:36.692000+01:00
# 664   900000820 2024-11-17 16:11:34.915000+01:00
# 718   900000769 2024-11-17 16:11:35.353000+01:00
# 487   900000670 2024-11-17 16:11:33.505000+01:00
# 795   900000881 2024-11-17 16:11:36.211000+01:00
# 1256  900001380 2024-11-17 16:11:42.008000+01:00
# 675   900000850 2024-11-17 16:11:34.995000+01:00
# 189   900000356 2024-11-17 16:11:29.412000+01:00
# 517   900000792 2024-11-17 16:11:33.732000+01:00
#
#                                path  latency res  res_desc grouppath
# 1817                         /order    18762  ok       200    /order
# 1930   /order/399/payment-callback'    18376  ok       200    /order
# 1805                         /order    16955  ok       200    /order
# 1294                         /order    15495  ok       200    /order
# 2070  /order/1188/payment-callback'    12729  ok       200    /order
# 1413                         /order    12016  ok       200    /order
# 786     /order/83/payment-callback'     9482  ok       200    /order
# 1504                         /order     6770  ok       200    /order
# 783    /order/283/payment-callback'     6738  ok       200    /order
# 357                          /order     6693  ok       200    /order
# 1856                         /order     6212  ok       200    /order
# 186                          /order     5447  ok       200    /order
# 1810                         /order     4891  ok       200    /order
# 914    /order/607/payment-callback'     4078  ko       400    /order
# 303    /order/214/payment-callback'     4023  ok       200    /order
# 207     /order/60/payment-callback'     3818  ok       200    /order
# 43                           /order     3781  ok       200    /order
# 1948                         /order     3256  ok       200    /order
# 1792                         /order     3209  ok       200    /order
# 2109                         /order     3085  ok       200    /order
# 1519  /order/1495/payment-callback'     3066  ok       200    /order
# 466                          /order     2597  ok       200    /order
# 1562  /order/1559/payment-callback'     2500  ok       200    /order
# 1804  /order/1878/payment-callback'      201  ok       200    /order
# 839    /order/955/payment-callback'       82  ok       200    /order
# 664    /order/820/payment-callback'        3  ko       400    /order
# 718    /order/769/payment-callback'        3  ko       400    /order
# 487    /order/670/payment-callback'        2  ko       400    /order
# 795    /order/881/payment-callback'        2  ko       400    /order
# 1256  /order/1380/payment-callback'        2  ko       400    /order
# 675    /order/850/payment-callback'        2  ko       400    /order
# 189    /order/356/payment-callback'        1  ko       400    /order
# 517    /order/792/payment-callback'        1  ko       400    /order

# %% [markdown]
# ## Indicateurs - résumé

# %%
d.describe()
# Out:
#                  id       latency     res_desc
# count  2.197000e+03   2197.000000  2197.000000
# mean   4.784715e+08   5769.157943   232.589895
# std    4.492007e+08   4996.594773    73.880730
# min    0.000000e+00      0.000000   200.000000
# 25%    8.420000e+02   2008.000000   200.000000
# 50%    9.000001e+08   4455.000000   200.000000
# 75%    9.000009e+08   8498.000000   200.000000
# max    9.000024e+08  26700.000000   400.000000

# %%
def histogroup(k):
    lat = d['latency'].loc[k]; ok = d['res'].loc[k]
    return "failed" if ok == "ko" else "t<20ms" if lat < 20 else "20ms<t<40ms" if lat < 40 else "40ms<t<200ms" if lat < 200 else "t>200ms"
histo = d.groupby(histogroup)['id'].count()
ordered_labels = ["failed", "t<20ms", "20ms<t<40ms", "40ms<t<200ms", "t>200ms"]; color_dict = {"t<20ms": '#4eac5b', "20ms<t<40ms": '#608ece', "40ms<t<200ms" : '#fffc54', "t>200ms" : '#ef7b36', "failed": 'r'}
histo = histo.reindex(pd.Categorical(histo.index,categories=ordered_labels,ordered=True)).sort_index()
colors = [color_dict[l] for l in histo.index]
histo.plot.bar(color=colors);

# %%
histo.plot.pie(colors=colors,figsize=(5,5));

# %%
def okcount(x):
    return x.value_counts().get("ok", 0)
def kocount(x):
    return x.value_counts().get("ko", 0)
def koper(x):
    return 100*(x.value_counts().get("ko", 0) / x.count())
def pct95th(x):
    print(x.values)
    print(x.count())
    print(x.quantile([1]))
    return x.quantile(0.95)
def pct99th(x):
    return x.quantile(0.99)
def reqpersec(x):
    return x.groupby(x.apply(lambda y: y.floor('s'))).count().mean()

#d.groupby(["grouppath"])
d.groupby(["grouppath"]).agg({'res': ['count',okcount,kocount,koper],'latency': ['mean','std','min','max'],'ts': [reqpersec]})
# d.groupby(["grouppath"]).agg({'res': [okcount]})
# Out:
#             res                                 latency                   \
#           count okcount kocount      koper         mean          std min
# grouppath
# /order     2197    1839     358  16.294948  5769.157943  4996.594773   0
#
#                          ts
#              max  reqpersec
# grouppath
# /order     26700  70.870968

# %% [markdown]
# ## Temps de réponse (ms)

# %%
d.groupby(d['grouppath'])['latency'].plot();

# %%
d.boxplot(column=['latency'], by='grouppath');
